# %% [markdown]
# # Chapter 3 — Classify images with a vision transformer
#
# Follow the matching chapter from your local copy of the book. Add explanations and code here as you work through it.

# %%
import torchvision

trainset = torchvision.datasets.CIFAR10(root=r".", train=True, download=True)
# Out:
#  39%|███▊      | 65.9M/170M [12:51<24:52, 70.1kB/s]

# %%
names = ["plane", "car", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,6),dpi=100)
for i in range(3):
    for j in range(6):
        plt.subplot(3, 6, 6*i+j+1)
        plt.imshow(trainset[6*i+j][0])
        plt.axis('off')
        plt.title(names[trainset[6*i+j][1]], fontsize=12)
plt.subplots_adjust(hspace=0.20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4 plt.figure(figsize=(12,6),dpi=100)
#       5 for i in range(3):
#       6     for j in range(6):
#       7         plt.subplot(3, 6, 6*i+j+1)
# ----> 8         plt.imshow(trainset[6*i+j][0])
#       9         plt.axis('off')
#      10         plt.title(names[trainset[6*i+j][1]], fontsize=12)
#      11 plt.subplots_adjust(hspace=0.20)
#
# NameError: name 'trainset' is not defined

# %%
testset=torchvision.datasets.CIFAR10(root=r'.',
                          train=False, download=True)

# %%
import torchvision.transforms as transforms

trainset.transform = transforms.Compose(
    [transforms.ToTensor(),
    transforms.Resize((32, 32),antialias=True),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomResizedCrop((32, 32), scale=(0.8, 1.0),
                 ratio=(0.75, 1.3333333333333333),
                 interpolation=2,antialias=True),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
import torch

trainloader = torch.utils.data.DataLoader(
    trainset,
    batch_size=32,
    shuffle=True
)
